# %%
# File: flows/b_training_ada.py
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier

from exercises.c_DevelopmentAndTraining.generic_trainer import train_fraud
from helpers.domino_short_id import domino_short_id
from helpers.dataset_utils import load_from_data_source


# Load DataFrame from data source
transformed_df_filename = 'transformed_cc_transactions.csv'

ada_model = {'model': AdaBoostClassifier(
            n_estimators=10,
            learning_rate=0.001,
            algorithm="SAMME",
        ), 'name': "AdaBoost"}
gnb_model = {'model': GaussianNB(), 
             'name': "GaussianNB"}
xbg_model = {'model': XGBClassifier(
            n_estimators=200,
            learning_rate=0.05,
            max_depth=4,
            subsample=0.8,
            colsample_bytree=0.8,
            use_label_encoder=False,
            eval_metric="auc",
        ), 'name': "XGBoost"}

all_models = [ada_model, gnb_model, xbg_model]

for model_dict in all_models:
    model_name = model_dict['name']
    model_obj = model_dict['model']
    res = train_fraud(model_obj, model_name, transformed_df_filename)
    print(f"✅ Training {model_name} completed successfully")
    print(res)
    
print(f"{'✅' * len(all_models)} Trainings completed successfully")
# Out:
# training model AdaBoost
# 🏃 View run AdaBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/aebac0dc7ff744cd91cada3ccb2141a0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# ✅ Training AdaBoost completed successfully
# {'model_name': 'AdaBoost', 'roc_auc': 0.8717215868194539, 'pr_auc': 0.7683758048261189, 'accuracy': 0.8194534386737469, 'precision_fraud': 0.7959442332065906, 'recall_fraud': 0.6740608228980322, 'f1_fraud': 0.7299496319256102, 'fit_time_sec': 1.3663485050201416}
# training model GaussianNB
# 🏃 View run GaussianNB at: http://127.0.0.1:8768/#/experiments/1566/runs/a6b5b76b472540b6b1b8e5594604e7cd
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# ✅ Training GaussianNB completed successfully
# {'model_name': 'GaussianNB', 'roc_auc': 0.8652405875290616, 'pr_auc': 0.7418668718181737, 'accuracy': 0.723675689677503, 'precision_fraud': 0.7816091954022989, 'recall_fraud': 0.32844364937388193, 'f1_fraud': 0.4625267665952891, 'fit_time_sec': 0.031319379806518555}
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/8442dd90da254860bc448cb91e7b9cee
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# ✅ Training XGBoost completed successfully
# {'model_name': 'XGBoost', 'roc_auc': 0.9333303372924653, 'pr_auc': 0.901069652766484, 'accuracy': 0.8512498381038726, 'precision_fraud': 0.8176731622612387, 'recall_fraud': 0.7581395348837209, 'f1_fraud': 0.7867817692379095, 'fit_time_sec': 8.211510181427002}
# ✅✅✅ Trainings completed successfully

# %%
from xgboost import XGBClassifier
from exercises.c_DevelopmentAndTraining.generic_trainer import train_fraud
import numpy as np

# Load DataFrame from dataset
transformed_df_filename = 'transformed_cc_transactions.csv'
model_name = 'XGBoost'

for i in range(50):
   # Randomize hyperparameters for each iteration
   model_obj = XGBClassifier(
       n_estimators=np.random.randint(100, 300),
       learning_rate=np.random.uniform(0.01, 0.1),
       max_depth=np.random.randint(3, 7),
       subsample=np.random.uniform(0.7, 1.0),
       colsample_bytree=np.random.uniform(0.7, 1.0),
       reg_alpha=np.random.uniform(0, 1),
       reg_lambda=np.random.uniform(1, 3),
       random_state=np.random.randint(0, 10000),  # Different seed each time
       use_label_encoder=False,
       eval_metric="auc",
   )
   
   res = train_fraud(model_obj, model_name, transformed_df_filename, random_state=i)
   print(f"Iteration {i+1}: Training {model_name} completed successfully")
   print(f"Params: n_est={model_obj.n_estimators}, lr={model_obj.learning_rate:.3f}, "
         f"depth={model_obj.max_depth}, subsample={model_obj.subsample:.2f}")
   print(f"Results: AUC={res['roc_auc']:.3f}, F1={res['f1_fraud']:.3f}")
   print("-" * 50)
# Out:
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/3152cacfc3e446bcb7ebd1bd008165cf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 1: Training XGBoost completed successfully
# Params: n_est=120, lr=0.057, depth=4, subsample=0.86
# Results: AUC=0.934, F1=0.781
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/1104d7000ff74d8494ca31290a4b805d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 2: Training XGBoost completed successfully
# Params: n_est=185, lr=0.094, depth=3, subsample=0.85
# Results: AUC=0.933, F1=0.785
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/095fa249351e4ffd94d7f975f58c8c4e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 3: Training XGBoost completed successfully
# Params: n_est=291, lr=0.032, depth=5, subsample=0.78
# Results: AUC=0.936, F1=0.783
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/1d79b4a2e4e94b338bb972e186261ced
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 4: Training XGBoost completed successfully
# Params: n_est=164, lr=0.039, depth=6, subsample=0.95
# Results: AUC=0.931, F1=0.788
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/426cca9ed0774eda8264fac995f7456a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 5: Training XGBoost completed successfully
# Params: n_est=153, lr=0.014, depth=4, subsample=0.73
# Results: AUC=0.930, F1=0.788
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/228ef62d8b7a45809d4c83c5fd9fc96f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 6: Training XGBoost completed successfully
# Params: n_est=260, lr=0.014, depth=6, subsample=0.75
# Results: AUC=0.931, F1=0.792
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/8268360332124f23855470f1edd8eb04
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 7: Training XGBoost completed successfully
# Params: n_est=225, lr=0.019, depth=4, subsample=0.78
# Results: AUC=0.932, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/8c2e1344999d4b03afc8838fae448558
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 8: Training XGBoost completed successfully
# Params: n_est=204, lr=0.080, depth=5, subsample=0.95
# Results: AUC=0.933, F1=0.785
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/ad55ad4195364c6889f063e94d25deaf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 9: Training XGBoost completed successfully
# Params: n_est=260, lr=0.074, depth=5, subsample=0.78
# Results: AUC=0.934, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/0b4f99bcfc63424795181dc96444cf97
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 10: Training XGBoost completed successfully
# Params: n_est=295, lr=0.011, depth=3, subsample=0.93
# Results: AUC=0.929, F1=0.778
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/d0c709a9ed554abb8a2dff29065d2a1b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 11: Training XGBoost completed successfully
# Params: n_est=274, lr=0.051, depth=5, subsample=0.99
# Results: AUC=0.934, F1=0.787
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/a9442e422d8e4b30af768c3d13db54a4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 12: Training XGBoost completed successfully
# Params: n_est=141, lr=0.095, depth=6, subsample=0.77
# Results: AUC=0.936, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/84c6081cbd974057854d99d42adcf13c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 13: Training XGBoost completed successfully
# Params: n_est=140, lr=0.047, depth=3, subsample=0.81
# Results: AUC=0.934, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/eb9cf71506694343986ad9ff728d90c1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 14: Training XGBoost completed successfully
# Params: n_est=119, lr=0.048, depth=6, subsample=0.93
# Results: AUC=0.937, F1=0.792
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/b27cd5f741d04a58a82146d372b862d8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 15: Training XGBoost completed successfully
# Params: n_est=104, lr=0.070, depth=6, subsample=0.90
# Results: AUC=0.934, F1=0.788
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/025a831713c44e7fbd5a1e35dc7c3da5
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 16: Training XGBoost completed successfully
# Params: n_est=202, lr=0.083, depth=4, subsample=0.87
# Results: AUC=0.934, F1=0.783
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/7426268597a94d16ae63ec31445c2c3e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 17: Training XGBoost completed successfully
# Params: n_est=146, lr=0.031, depth=4, subsample=0.99
# Results: AUC=0.935, F1=0.792
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/e2374e64d4644e149fd7bf8fe3672a97
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 18: Training XGBoost completed successfully
# Params: n_est=241, lr=0.048, depth=5, subsample=0.75
# Results: AUC=0.932, F1=0.783
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/ea2b73322e434bcea10949315a4cd9a7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 19: Training XGBoost completed successfully
# Params: n_est=241, lr=0.022, depth=4, subsample=0.81
# Results: AUC=0.930, F1=0.781
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/5a4d7fce48c240f99fbfa0de30c17863
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 20: Training XGBoost completed successfully
# Params: n_est=176, lr=0.048, depth=5, subsample=0.71
# Results: AUC=0.929, F1=0.772
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/4e0f8f2427aa4fc4b1cb43aa7c42ff29
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 21: Training XGBoost completed successfully
# Params: n_est=217, lr=0.018, depth=6, subsample=0.71
# Results: AUC=0.932, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/656a0d3b5d8c4a1396106045afb93bc2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 22: Training XGBoost completed successfully
# Params: n_est=141, lr=0.027, depth=4, subsample=0.85
# Results: AUC=0.933, F1=0.788
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/e6db93e926a04f0b92d7fe9faab987d8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 23: Training XGBoost completed successfully
# Params: n_est=260, lr=0.092, depth=6, subsample=0.94
# Results: AUC=0.933, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/cf862feca0fe435681c0cfdbadb39fd9
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 24: Training XGBoost completed successfully
# Params: n_est=274, lr=0.072, depth=4, subsample=0.94
# Results: AUC=0.935, F1=0.791
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/721f576b336140a89195f69f32c4f38a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 25: Training XGBoost completed successfully
# Params: n_est=169, lr=0.022, depth=4, subsample=0.92
# Results: AUC=0.935, F1=0.793
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/f434208ad6ea498bb4b4239200f0f917
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 26: Training XGBoost completed successfully
# Params: n_est=134, lr=0.023, depth=3, subsample=0.90
# Results: AUC=0.928, F1=0.775
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/1b6502129c5e463f92a3327567b073ce
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 27: Training XGBoost completed successfully
# Params: n_est=151, lr=0.058, depth=4, subsample=0.88
# Results: AUC=0.935, F1=0.788
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/0f609b0163a740ed8bc8af5139e46775
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 28: Training XGBoost completed successfully
# Params: n_est=184, lr=0.058, depth=6, subsample=0.71
# Results: AUC=0.931, F1=0.784
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/387743b8957f42f0a1dc59eb1f2b8a3b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 29: Training XGBoost completed successfully
# Params: n_est=150, lr=0.043, depth=5, subsample=0.75
# Results: AUC=0.931, F1=0.779
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/2500c4322fd249609a77964287a54de0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 30: Training XGBoost completed successfully
# Params: n_est=133, lr=0.057, depth=3, subsample=0.83
# Results: AUC=0.936, F1=0.791
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/164f2480fe5545eb991f15b3bcebf9a8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 31: Training XGBoost completed successfully
# Params: n_est=104, lr=0.036, depth=6, subsample=0.84
# Results: AUC=0.930, F1=0.773
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/e72f254c9dcb4e1982efe9dac13c58c1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 32: Training XGBoost completed successfully
# Params: n_est=199, lr=0.025, depth=5, subsample=0.82
# Results: AUC=0.934, F1=0.796
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/4f7a3873d9ce41e89196a6031421570f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 33: Training XGBoost completed successfully
# Params: n_est=109, lr=0.042, depth=4, subsample=0.76
# Results: AUC=0.932, F1=0.786
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/89c4629d4a644c4391c9b8913a70d39d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 34: Training XGBoost completed successfully
# Params: n_est=215, lr=0.061, depth=6, subsample=0.96
# Results: AUC=0.928, F1=0.780
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/3fe5c3c317b7456099537b446b156504
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 35: Training XGBoost completed successfully
# Params: n_est=292, lr=0.087, depth=5, subsample=0.87
# Results: AUC=0.932, F1=0.781
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/efb857b24bfd468d9b8c411cdd33e30e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 36: Training XGBoost completed successfully
# Params: n_est=168, lr=0.094, depth=6, subsample=0.91
# Results: AUC=0.935, F1=0.790
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/eb71efa7488d4ad4abb02b98289d22cb
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 37: Training XGBoost completed successfully
# Params: n_est=262, lr=0.033, depth=5, subsample=0.71
# Results: AUC=0.932, F1=0.786
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/da9efcdbc04b43cc9076740bbfa93971
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 38: Training XGBoost completed successfully
# Params: n_est=262, lr=0.031, depth=6, subsample=0.87
# Results: AUC=0.935, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/91e2940e1c22450da893d5c0e6328908
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 39: Training XGBoost completed successfully
# Params: n_est=133, lr=0.050, depth=4, subsample=0.95
# Results: AUC=0.934, F1=0.790
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/89e631f556b84a749deb5db002c6b57a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 40: Training XGBoost completed successfully
# Params: n_est=185, lr=0.015, depth=3, subsample=0.87
# Results: AUC=0.929, F1=0.771
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/391bcca566d2499f9dc84d8994d372c2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 41: Training XGBoost completed successfully
# Params: n_est=172, lr=0.093, depth=5, subsample=0.99
# Results: AUC=0.934, F1=0.789
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/21b7ca0c9935458282bce558a0640168
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 42: Training XGBoost completed successfully
# Params: n_est=199, lr=0.018, depth=6, subsample=0.92
# Results: AUC=0.935, F1=0.776
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/0a3c206a8c8f4556a6010927e5148a38
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 43: Training XGBoost completed successfully
# Params: n_est=200, lr=0.039, depth=3, subsample=0.98
# Results: AUC=0.931, F1=0.786
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/f8e533bfa0c241dba8ac3f054d6d5ded
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 44: Training XGBoost completed successfully
# Params: n_est=277, lr=0.089, depth=4, subsample=0.78
# Results: AUC=0.933, F1=0.786
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/0162a8e0681c48b6a13541f579e9d3a1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 45: Training XGBoost completed successfully
# Params: n_est=195, lr=0.020, depth=4, subsample=0.89
# Results: AUC=0.932, F1=0.786
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/4c5dffb262114aca85ebd8d4d542f14e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 46: Training XGBoost completed successfully
# Params: n_est=202, lr=0.064, depth=6, subsample=0.93
# Results: AUC=0.933, F1=0.783
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/da5ea59fe05b471ba3a984f4001774e8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 47: Training XGBoost completed successfully
# Params: n_est=192, lr=0.043, depth=4, subsample=0.70
# Results: AUC=0.932, F1=0.782
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/4cb0301b97214fe7a5261f96bccbb1c8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 48: Training XGBoost completed successfully
# Params: n_est=261, lr=0.086, depth=3, subsample=0.79
# Results: AUC=0.933, F1=0.786
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/61085fccc03f409885dfec5d8027aef3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 49: Training XGBoost completed successfully
# Params: n_est=114, lr=0.031, depth=3, subsample=0.86
# Results: AUC=0.932, F1=0.776
# --------------------------------------------------
# training model XGBoost
# 🏃 View run XGBoost at: http://127.0.0.1:8768/#/experiments/1566/runs/c1aa33630aac4b4bb1190fff3c57886c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1566
# Iteration 50: Training XGBoost completed successfully
# Params: n_est=125, lr=0.010, depth=5, subsample=0.96
# Results: AUC=0.932, F1=0.791
# --------------------------------------------------

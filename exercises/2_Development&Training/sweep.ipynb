# %%
def generate_synthetic_demo(...):
    # … steps 1–6 unchanged …

    # 7) Stronger outlier injection (1% of the data, huge multipliers)
    mask = np.random.rand(n_samples) < 0.01  # 1% instead of 0.1%
    # Increase range so values jump 20–100×
    factor = np.random.uniform(20, 100, size=mask.sum())
    for col in ["Amount","IPReputation","MerchantRisk","Txn24h","Avg30d"]:
        df.loc[mask, col] *= factor

    # 7b) Force-classify them as fraud
    df.loc[mask, "Class"] = 1

    # 7c) Optional: add an explicit outlier indicator
    df["OutlierFlag"] = 0
    df.loc[mask, "OutlierFlag"] = 1
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# ...
